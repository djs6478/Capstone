# %%
import numpy as np
import pandas as pd
# Data visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# Pre-Processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.preprocessing import OneHotEncoder
# StatsModel and Metrics
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.feature_selection import SelectKBest, mutual_info_regression

# %%
standardstats = pd.read_excel('Premier league 2019-2020 standard stats.xlsx')
standardstats
# Out:
#       Rk                Player   Nation    Pos            Squad  Age  Born  \
# 0      1   Patrick van Aanholt   nl NED     DF   Crystal Palace   28  1990
# 1      2            Max Aarons  eng ENG     DF     Norwich City   19  2000
# 2      3         Tammy Abraham  eng ENG     FW          Chelsea   21  1997
# 3      4             Che Adams  sct SCO     FW      Southampton   23  1996
# 4      5                Adrián   es ESP     GK        Liverpool   32  1987
# ..   ...                   ...      ...    ...              ...  ...   ...
# 517  518         Wilfried Zaha   ci CIV  MF,FW   Crystal Palace   26  1992
# 518  519  Christoph Zimmermann   de GER     DF     Norwich City   26  1993
# 519  520   Oleksandr Zinchenko   ua UKR     DF  Manchester City   22  1996
# 520  521     Richairo Živković   nl NED     FW    Sheffield Utd   22  1996
# 521  522            Kurt Zouma   fr FRA     DF          Chelsea   24  1994
#
# ...

# %%
standardstats = standardstats.drop_duplicates(subset=['Player'])

# %%
standardstats['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
standardstats = standardstats.dropna()

# %%
standardstats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515 entries, 0 to 521
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          515 non-null    int64
#  1   Player      515 non-null    object
#  2   Nation      515 non-null    object
#  3   Pos         515 non-null    object
#  4   Squad       515 non-null    object
#  5   Age         515 non-null    int64
#  6   Born        515 non-null    int64
#  7   MP          515 non-null    int64
#  8   Starts      515 non-null    int64
#  9   Min         515 non-null    int64
#  10  Gls         515 non-null    int64
#  11  Ast         515 non-null    int64
#  12  Gls_90      515 non-null    float64
#  13  Ast_90      515 non-null    float64
#  14  G+A_90      515 non-null    float64
#  15  G-PK_90     515 non-null    float64
#  16  G+A-PK_90   515 non-null    float64
#  17  xG_90       515 non-null    float64
#  18  xA_90       515 non-null    float64
# ...

# %%
shotcreation = pd.read_excel('Premier league 2019-2020 shotcreation.xlsx')
shotcreation
# Out:
#       Rk                Player  SCA  SCA90  PassLive  PassDead  Drib  Sh  Fld  \
# 0      1   Patrick van Aanholt   62   2.23        32        23     3   2    2
# 1      2            Max Aarons   55   1.53        42         2     3   3    4
# 2      3         Tammy Abraham   50   2.03        33         0     6   6    2
# 3      4             Che Adams   25   2.03        15         0     3   2    4
# 4      5                Adrián    2   0.21         2         0     0   0    0
# ..   ...                   ...  ...    ...       ...       ...   ...  ..  ...
# 517  518         Wilfried Zaha  106   2.91        62         0    22   5   15
# 518  519  Christoph Zimmermann    4   0.25         1         0     0   0    0
# 519  520   Oleksandr Zinchenko   31   2.19        30         1     0   0    0
# 520  521     Richairo Živković    2   1.61         2         0     0   0    0
# 521  522            Kurt Zouma   14   0.54        12         0     0   1    1
#
# ...

# %%
shotcreation = shotcreation.drop_duplicates(subset=['Player'])

# %%
shotcreation = shotcreation.dropna()

# %%
shotcreation['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
shotcreation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515 entries, 0 to 521
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          515 non-null    int64
#  1   Player      515 non-null    object
#  2   SCA         515 non-null    int64
#  3   SCA90       515 non-null    float64
#  4   PassLive    515 non-null    int64
#  5   PassDead    515 non-null    int64
#  6   Drib        515 non-null    int64
#  7   Sh          515 non-null    int64
#  8   Fld         515 non-null    int64
#  9   Def         515 non-null    int64
#  10  GCA         515 non-null    int64
#  11  GCA90       515 non-null    float64
#  12  PassLive.1  515 non-null    int64
#  13  PassDead.1  515 non-null    int64
#  14  Drib.1      515 non-null    int64
#  15  Sh.1        515 non-null    int64
#  16  Fld.1       515 non-null    int64
#  17  Def.1       515 non-null    int64
# dtypes: float64(2), int64(15), object(1)
# ...

# %%
shooting_stats = pd.read_excel('Premier league 2019-2020 shooting stats.xlsx')
shooting_stats
# Out:
#       Rk                Player  Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  \
# 0      1   Patrick van Aanholt  26    5  19.2   0.93    0.18  0.08   0.40
# 1      2            Max Aarons  14    4  28.6   0.39    0.11  0.00   0.00
# 2      3         Tammy Abraham  88   35  39.8   3.58    1.42  0.17   0.43
# 3      4             Che Adams  37    9  24.3   3.00    0.73  0.11   0.44
# 4      5                Adrián   0    0   NaN   0.00    0.00   NaN    NaN
# ..   ...                   ...  ..  ...   ...    ...     ...   ...    ...
# 517  518         Wilfried Zaha  61   17  27.9   1.67    0.47  0.07   0.24
# 518  519  Christoph Zimmermann   6    1  16.7   0.38    0.06  0.00   0.00
# 519  520   Oleksandr Zinchenko  16    3  18.8   1.13    0.21  0.00   0.00
# 520  521     Richairo Živković   1    0   0.0   0.80    0.00  0.00    NaN
# 521  522            Kurt Zouma  15    5  33.3   0.58    0.19  0.00   0.00
#
#      Dist  npxG/Sh  G-xG  np:G-xG
# 0    21.0     0.06   0.6      0.4
# ...

# %%
shooting_stats = shooting_stats.drop_duplicates(subset=['Player'])

# %%
shooting_stats['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
npxG_90 = standardstats['npxG_90']

# %%
shooting = shooting_stats.join(npxG_90)

# %%
shooting.drop('G/SoT',axis=1,inplace=True)

# %%
shooting = shooting.dropna()

# %%
shooting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 521
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       435 non-null    int64
#  1   Player   435 non-null    object
#  2   Sh       435 non-null    int64
#  3   SoT      435 non-null    int64
#  4   SoT%     435 non-null    float64
#  5   Sh/90    435 non-null    float64
#  6   SoT/90   435 non-null    float64
#  7   G/Sh     435 non-null    float64
#  8   Dist     435 non-null    float64
#  9   npxG/Sh  435 non-null    float64
#  10  G-xG     435 non-null    float64
#  11  np:G-xG  435 non-null    float64
#  12  npxG_90  435 non-null    float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 47.6+ KB

# %%
pass_stats = pd.read_excel('Premier league 2019-2020 passing stats.xlsx')
pass_stats
# Out:
#       Rk                Player   Cmp   Att  Cmp%  Cmp%short  Cmp%med  \
# 0      1   Patrick van Aanholt  1227  1558  78.8       89.3     82.2
# 1      2            Max Aarons  1316  1684  78.1       89.4     79.7
# 2      3         Tammy Abraham   288   412  69.9       71.6     76.2
# 3      4             Che Adams   184   265  69.4       77.4     72.5
# 4      5                Adrián   227   314  72.3      100.0     98.1
# ..   ...                   ...   ...   ...   ...        ...      ...
# 517  518         Wilfried Zaha   935  1188  78.7       85.8     82.2
# 518  519  Christoph Zimmermann   492   609  80.8       93.3     90.3
# 519  520   Oleksandr Zinchenko  1198  1348  88.9       93.0     89.2
# 520  521     Richairo Živković    16    18  88.9       90.0     83.3
# 521  522            Kurt Zouma  1772  1982  89.4       92.4     93.7
#
#      Cmp%long  KP  Prog_pass
# 0        50.7  32        129
# 1        44.8  24         77
# 2        74.3  18         31
# ...

# %%
pass_stats = pass_stats.drop_duplicates(subset=['Player'])

# %%
pass_stats['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
passtypes = pd.read_excel('Premier league 2019-2020 pass types.xlsx')
passtypes
# Out:
#       Rk                Player  PassInt  Blocked
# 0      1   Patrick van Aanholt       36       47
# 1      2            Max Aarons       22       70
# 2      3         Tammy Abraham        8       26
# 3      4             Che Adams        8       20
# 4      5                Adrián        0        1
# ..   ...                   ...      ...      ...
# 517  518         Wilfried Zaha       34       72
# 518  519  Christoph Zimmermann        5        8
# 519  520   Oleksandr Zinchenko       14       22
# 520  521     Richairo Živković        0        0
# 521  522            Kurt Zouma       13       13
#
# [522 rows x 4 columns]

# %%
passtypes = passtypes.drop_duplicates(subset=['Player'])

# %%
passtypes['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
passing_1merge = pd.merge(pass_stats,passtypes)

# %%
passing_2merge = pd.merge(passing_1merge,shotcreation)

# %%
passing = pd.merge(passing_2merge, standardstats)
passing
# Out:
#       Rk                Player   Cmp   Att  Cmp%  Cmp%short  Cmp%med  \
# 0      1   Patrick van Aanholt  1227  1558  78.8       89.3     82.2
# 1      2            Max Aarons  1316  1684  78.1       89.4     79.7
# 2      3         Tammy Abraham   288   412  69.9       71.6     76.2
# 3      4             Che Adams   184   265  69.4       77.4     72.5
# 4      5                Adrián   227   314  72.3      100.0     98.1
# ..   ...                   ...   ...   ...   ...        ...      ...
# 510  518         Wilfried Zaha   935  1188  78.7       85.8     82.2
# 511  519  Christoph Zimmermann   492   609  80.8       93.3     90.3
# 512  520   Oleksandr Zinchenko  1198  1348  88.9       93.0     89.2
# 513  521     Richairo Živković    16    18  88.9       90.0     83.3
# 514  522            Kurt Zouma  1772  1982  89.4       92.4     93.7
#
#      Cmp%long  KP  Prog_pass  ...  Gls_90  Ast_90  G+A_90  G-PK_90  G+A-PK_90  \
# ...

# %%
passing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515 entries, 0 to 514
# Data columns (total 48 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          515 non-null    int64
#  1   Player      515 non-null    object
#  2   Cmp         515 non-null    int64
#  3   Att         515 non-null    int64
#  4   Cmp%        511 non-null    float64
#  5   Cmp%short   508 non-null    float64
#  6   Cmp%med     507 non-null    float64
#  7   Cmp%long    488 non-null    float64
#  8   KP          515 non-null    int64
#  9   Prog_pass   515 non-null    int64
#  10  PassInt     515 non-null    int64
#  11  Blocked     515 non-null    int64
#  12  SCA         515 non-null    int64
#  13  SCA90       515 non-null    float64
#  14  PassLive    515 non-null    int64
#  15  PassDead    515 non-null    int64
#  16  Drib        515 non-null    int64
#  17  Sh          515 non-null    int64
#  18  Fld         515 non-null    int64
# ...

# %%
passing.drop('Gls_90', axis =1, inplace=True)

# %%
passing.drop('Ast',axis =1, inplace=True)

# %%
passing.drop('G+A_90',axis = 1, inplace=True)

# %%
passing.drop('G-PK_90',axis=1, inplace=True)

# %%
passing.drop('G+A-PK_90',axis=1, inplace=True)

# %%
passing.drop('xG_90', axis =1, inplace=True)

# %%
passing.drop('xG+xA_90',axis =1, inplace=True)

# %%
passing.drop('npxG_90',axis =1, inplace=True)

# %%
passing.drop('npxG+xA_90', axis = 1, inplace=True)

# %%
passing.drop('Nation', axis =1, inplace=True)

# %%
passing.drop('Pos', axis=1, inplace=True)

# %%
passing.drop('Squad',axis=1, inplace=True)

# %%
passing.drop('Drib',axis=1, inplace=True)

# %%
passing.drop('Sh',axis=1, inplace=True)

# %%
passing.drop('Fld',axis=1, inplace=True)

# %%
passing.drop('Def',axis=1, inplace=True)

# %%
passing.drop('Drib.1',axis=1, inplace=True)

# %%
passing.drop('Sh.1',axis=1, inplace=True)

# %%
passing.drop('Fld.1',axis=1, inplace=True)

# %%
passing.drop('Def.1',axis=1, inplace=True)

# %%
passing.drop('Born',axis=1, inplace=True)

# %%
passing.drop('Starts', axis=1,inplace=True)

# %%
passing.drop('Gls', axis=1, inplace =True)

# %%
passing.drop('GCA', axis=1, inplace=True)

# %%
passing.drop('GCA90', axis = 1, inplace =True)

# %%
passing.drop('SCA', axis = 1,inplace =True)

# %%
passing.drop('SCA90',axis=1,inplace=True)

# %%
passing.drop('PassLive.1', axis =1,inplace=True)

# %%
passing.drop('PassDead.1', axis =1,inplace =True)

# %%
passing.dropna(inplace=True)

# %%
passing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 514
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rk         483 non-null    int64
#  1   Player     483 non-null    object
#  2   Cmp        483 non-null    int64
#  3   Att        483 non-null    int64
#  4   Cmp%       483 non-null    float64
#  5   Cmp%short  483 non-null    float64
#  6   Cmp%med    483 non-null    float64
#  7   Cmp%long   483 non-null    float64
#  8   KP         483 non-null    int64
#  9   Prog_pass  483 non-null    int64
#  10  PassInt    483 non-null    int64
#  11  Blocked    483 non-null    int64
#  12  PassLive   483 non-null    int64
#  13  PassDead   483 non-null    int64
#  14  Age        483 non-null    int64
#  15  MP         483 non-null    int64
#  16  Min        483 non-null    int64
#  17  Ast_90     483 non-null    float64
#  18  xA_90      483 non-null    float64
# ...

# %%
passing
# Out:
#       Rk                Player   Cmp   Att  Cmp%  Cmp%short  Cmp%med  \
# 0      1   Patrick van Aanholt  1227  1558  78.8       89.3     82.2
# 1      2            Max Aarons  1316  1684  78.1       89.4     79.7
# 2      3         Tammy Abraham   288   412  69.9       71.6     76.2
# 3      4             Che Adams   184   265  69.4       77.4     72.5
# 4      5                Adrián   227   314  72.3      100.0     98.1
# ..   ...                   ...   ...   ...   ...        ...      ...
# 510  518         Wilfried Zaha   935  1188  78.7       85.8     82.2
# 511  519  Christoph Zimmermann   492   609  80.8       93.3     90.3
# 512  520   Oleksandr Zinchenko  1198  1348  88.9       93.0     89.2
# 513  521     Richairo Živković    16    18  88.9       90.0     83.3
# 514  522            Kurt Zouma  1772  1982  89.4       92.4     93.7
#
#      Cmp%long  KP  Prog_pass  PassInt  Blocked  PassLive  PassDead  Age  MP  \
# ...

# %%
defending_stats = pd.read_excel('Premier league 2019-2020 defensive actions.xlsx')
defending_stats
# Out:
#       Rk                Player  Tkl  TklW  Tkl_d  Att_d  Tkl%_d  \
# 0      1   Patrick van Aanholt   51    32     22     54    40.7
# 1      2            Max Aarons   64    36     21     45    46.7
# 2      3         Tammy Abraham   14    10      4     16    25.0
# 3      4             Che Adams    8     6      0      5     0.0
# 4      5                Adrián    0     0      0      1     0.0
# ..   ...                   ...  ...   ...    ...    ...     ...
# 517  518         Wilfried Zaha   45    31     10     45    22.2
# 518  519  Christoph Zimmermann   31    21     16     25    64.0
# 519  520   Oleksandr Zinchenko   28    16     17     39    43.6
# 520  521     Richairo Živković    2     2      0      1     0.0
# 521  522            Kurt Zouma   33    17      3      8    37.5
#
#      PlayersLetPast  Press  PressSucc  PressSucc%  Blocks  Int  Clr  Err
# 0                32    267         74        27.7      57   23   67    3
# ...

# %%
defending_stats = defending_stats.drop_duplicates(subset=['Player'])

# %%
defending_stats['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
playing_time = pd.read_excel('Premier league 2019-2020 Squad playingtime.xlsx')
playing_time
# Out:
#       Rk                Player  xG+/-90  On-Off
# 0      1   Patrick van Aanholt    -0.38    0.28
# 1      2            Max Aarons    -0.62    0.14
# 2      3         Tammy Abraham     0.69   -0.17
# 3      4             Che Adams     0.11    0.13
# 4      5                Adrián     0.94    0.16
# ..   ...                   ...      ...     ...
# 616  617         Wilfried Zaha    -0.41    1.01
# 617  618  Christoph Zimmermann    -0.35    0.47
# 618  619   Oleksandr Zinchenko     1.42   -0.18
# 619  620     Richairo Živković    -1.27   -1.14
# 620  621            Kurt Zouma     0.71   -0.15
#
# [621 rows x 4 columns]

# %%
playing_time = playing_time.drop_duplicates(subset=['Player'])

# %%
playing_time['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Connor Wickham        1
# Matt Doherty          1
# Ezri Konsa            1
# Taylor Perry          1
#                      ..
# Brandon Williams      1
# Raheem Sterling       1
# Jack Wilshere         1
# Oriol Romeu           1
# Paul Pogba            1
# Name: Player, Length: 614, dtype: int64

# %%
playing_time = playing_time.dropna()

# %%
playing_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 620
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       500 non-null    int64
#  1   Player   500 non-null    object
#  2   xG+/-90  500 non-null    float64
#  3   On-Off   500 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 19.5+ KB

# %%
playing_time_names = playing_time['Player']

# %%
playing_time_target = playing_time['xG+/-90']

# %%
playing_time_target_df = pd.concat([playing_time_names,playing_time_target],axis=1)

# %%
playing_time_target_df
# Out:
#                    Player  xG+/-90
# 0     Patrick van Aanholt    -0.38
# 1              Max Aarons    -0.62
# 2           Tammy Abraham     0.69
# 3               Che Adams     0.11
# 4                  Adrián     0.94
# ..                    ...      ...
# 616         Wilfried Zaha    -0.41
# 617  Christoph Zimmermann    -0.35
# 618   Oleksandr Zinchenko     1.42
# 619     Richairo Živković    -1.27
# 620            Kurt Zouma     0.71
#
# [500 rows x 2 columns]

# %%
defending = pd.merge(defending_stats,playing_time_target_df, on='Player')

# %%
defending['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Angus Gunn            1
# Kieran Tierney        1
# Jed Steer             1
# Connor Wickham        1
#                      ..
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Tariq Lamptey         1
# Paul Pogba            1
# Name: Player, Length: 500, dtype: int64

# %%
defending = defending.dropna()

# %%
defending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 446 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rk              446 non-null    int64
#  1   Player          446 non-null    object
#  2   Tkl             446 non-null    int64
#  3   TklW            446 non-null    int64
#  4   Tkl_d           446 non-null    int64
#  5   Att_d           446 non-null    int64
#  6   Tkl%_d          446 non-null    float64
#  7   PlayersLetPast  446 non-null    int64
#  8   Press           446 non-null    int64
#  9   PressSucc       446 non-null    int64
#  10  PressSucc%      446 non-null    float64
#  11  Blocks          446 non-null    int64
#  12  Int             446 non-null    int64
#  13  Clr             446 non-null    int64
#  14  Err             446 non-null    int64
#  15  xG+/-90         446 non-null    float64
# dtypes: float64(3), int64(12), object(1)
# memory usage: 59.2+ KB

# %%
possession = pd.read_excel('Premier league 2019-2020 possession stats.xlsx')

# %%
possession = possession.drop_duplicates(subset=['Player'])

# %%
possession['Player'].value_counts()
# Out:
# Callum Hudson-Odoi    1
# Carlos Sánchez        1
# Connor Wickham        1
# Adam Webster          1
# Mattéo Guendouzi      1
#                      ..
# Jonjo Shelvey         1
# Enda Stevens          1
# Tom Davies            1
# Marcos Rojo           1
# Paul Pogba            1
# Name: Player, Length: 515, dtype: int64

# %%
possession = possession.dropna()

# %%
possession.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 521
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          452 non-null    int64
#  1   Player      452 non-null    object
#  2   Touches     452 non-null    int64
#  3   Succ        452 non-null    int64
#  4   Att         452 non-null    int64
#  5   Succ%       452 non-null    float64
#  6   plyrs_past  452 non-null    int64
#  7   Prog_drib   452 non-null    int64
#  8   Mis         452 non-null    int64
#  9   Dis         452 non-null    int64
#  10  Targ        452 non-null    int64
#  11  Rec         452 non-null    int64
#  12  Rec%        452 non-null    float64
#  13  Prog_rec    452 non-null    int64
# dtypes: float64(2), int64(11), object(1)
# memory usage: 53.0+ KB

# %%
dribble_sca = shotcreation['Drib']

# %%
foul_sca = shotcreation['Fld']

# %%
names_sca = shotcreation['Player']

# %%
drib_concat_1 = pd.concat([dribble_sca, foul_sca], axis=1)

# %%
drib_join = drib_concat_1.join(names_sca)

# %%
drib_join
# Out:
#      Drib  Fld                Player
# 0       3    2   Patrick van Aanholt
# 1       3    4            Max Aarons
# 2       6    2         Tammy Abraham
# 3       3    4             Che Adams
# 4       0    0                Adrián
# ..    ...  ...                   ...
# 517    22   15         Wilfried Zaha
# 518     0    0  Christoph Zimmermann
# 519     0    0   Oleksandr Zinchenko
# 520     0    0     Richairo Živković
# 521     0    1            Kurt Zouma
#
# [515 rows x 3 columns]

# %%
dribbling = pd.merge(possession, drib_join,on='Player')

# %%
dribbling = pd.merge(dribbling, playing_time_target_df,on='Player')

# %%
dribbling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 441
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          442 non-null    int64
#  1   Player      442 non-null    object
#  2   Touches     442 non-null    int64
#  3   Succ        442 non-null    int64
#  4   Att         442 non-null    int64
#  5   Succ%       442 non-null    float64
#  6   plyrs_past  442 non-null    int64
#  7   Prog_drib   442 non-null    int64
#  8   Mis         442 non-null    int64
#  9   Dis         442 non-null    int64
#  10  Targ        442 non-null    int64
#  11  Rec         442 non-null    int64
#  12  Rec%        442 non-null    float64
#  13  Prog_rec    442 non-null    int64
#  14  Drib        442 non-null    int64
#  15  Fld         442 non-null    int64
#  16  xG+/-90     442 non-null    float64
# dtypes: float64(3), int64(13), object(1)
# memory usage: 62.2+ KB

# %%
goalkeeping = pd.read_excel('Premier league 2019-2020 gk stats.xlsx')

# %%
goalkeeping = goalkeeping.dropna()

# %%
goalkeeping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 36
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rk        36 non-null     int64
#  1   Player    36 non-null     object
#  2   Nation    36 non-null     object
#  3   Pos       36 non-null     object
#  4   Squad     36 non-null     object
#  5   Age       36 non-null     int64
#  6   Born      36 non-null     int64
#  7   90s       36 non-null     float64
#  8   GA        36 non-null     int64
#  9   PKA       36 non-null     int64
#  10  FK        36 non-null     int64
#  11  CK        36 non-null     int64
#  12  PSxG      36 non-null     float64
#  13  PSxG/SoT  36 non-null     float64
#  14  PSxG+/-   36 non-null     float64
#  15  /90       36 non-null     float64
#  16  Cmp       36 non-null     int64
#  17  Att       36 non-null     int64
#  18  Cmp%      36 non-null     float64
#  19  Stp       36 non-null     int64
# ...

# %%
misc = pd.read_excel('Premier league 2019-2020 misc.xlsx')

# %%
misc = misc.drop_duplicates('Player')

# %%
misc = misc.dropna()

# %%
misc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461 entries, 0 to 521
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       461 non-null    int64
#  1   Player   461 non-null    object
#  2   Recov    461 non-null    int64
#  3   AirWon   461 non-null    int64
#  4   AirLost  461 non-null    int64
#  5   AirWon%  461 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 25.2+ KB

# %%
heading = misc.drop('Recov',axis =1)

# %%
defending = pd.merge(defending,misc,on='Player')

# %%
defending
# Out:
#      Rk_x                Player  Tkl  TklW  Tkl_d  Att_d  Tkl%_d  \
# 0       1   Patrick van Aanholt   51    32     22     54    40.7
# 1       2            Max Aarons   64    36     21     45    46.7
# 2       3         Tammy Abraham   14    10      4     16    25.0
# 3       4             Che Adams    8     6      0      5     0.0
# 4       6         Sergio Agüero    7     5      1      6    16.7
# ..    ...                   ...  ...   ...    ...    ...     ...
# 425   518         Wilfried Zaha   45    31     10     45    22.2
# 426   519  Christoph Zimmermann   31    21     16     25    64.0
# 427   520   Oleksandr Zinchenko   28    16     17     39    43.6
# 428   521     Richairo Živković    2     2      0      1     0.0
# 429   522            Kurt Zouma   33    17      3      8    37.5
#
#      PlayersLetPast  Press  PressSucc  ...  Blocks  Int  Clr  Err  xG+/-90  \
# 0                32    267         74  ...      57   23   67    3    -0.38
# ...

# %%
shooting = pd.merge(shooting, heading, on='Player')

# %%
shooting
# Out:
#      Rk_x                Player  Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  Dist  \
# 0       1   Patrick van Aanholt  26    5  19.2   0.93    0.18  0.08  21.0
# 1       2            Max Aarons  14    4  28.6   0.39    0.11  0.00  17.8
# 2       3         Tammy Abraham  88   35  39.8   3.58    1.42  0.17  11.1
# 3       4             Che Adams  37    9  24.3   3.00    0.73  0.11  15.2
# 4       6         Sergio Agüero  73   25  34.2   4.52    1.55  0.19  12.9
# ..    ...                   ...  ..  ...   ...    ...     ...   ...   ...
# 422   518         Wilfried Zaha  61   17  27.9   1.67    0.47  0.07  15.8
# 423   519  Christoph Zimmermann   6    1  16.7   0.38    0.06  0.00  14.7
# 424   520   Oleksandr Zinchenko  16    3  18.8   1.13    0.21  0.00  25.6
# 425   521     Richairo Živković   1    0   0.0   0.80    0.00  0.00  13.9
# 426   522            Kurt Zouma  15    5  33.3   0.58    0.19  0.00  11.0
#
#      npxG/Sh  G-xG  np:G-xG  npxG_90  Rk_y  AirWon  AirLost  AirWon%
# ...

# %%
df_merge1 = pd.merge(shooting,passing,on='Player')

# %%
df_merge2 =pd.merge(df_merge1,defending,on='Player')

# %%
final_df = pd.merge(df_merge2,dribbling,on='Player')

# %%
standardstats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515 entries, 0 to 521
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          515 non-null    int64
#  1   Player      515 non-null    object
#  2   Nation      515 non-null    object
#  3   Pos         515 non-null    object
#  4   Squad       515 non-null    object
#  5   Age         515 non-null    int64
#  6   Born        515 non-null    int64
#  7   MP          515 non-null    int64
#  8   Starts      515 non-null    int64
#  9   Min         515 non-null    int64
#  10  Gls         515 non-null    int64
#  11  Ast         515 non-null    int64
#  12  Gls_90      515 non-null    float64
#  13  Ast_90      515 non-null    float64
#  14  G+A_90      515 non-null    float64
#  15  G-PK_90     515 non-null    float64
#  16  G+A-PK_90   515 non-null    float64
#  17  xG_90       515 non-null    float64
#  18  xA_90       515 non-null    float64
# ...

# %%
standardstats_names = standardstats['Player']

# %%
standardstats_age = standardstats['Age']

# %%
standardstats_pos = standardstats['Pos']

# %%
standardstats_club = standardstats['Squad']

# %%
standardstats_ga_90 = standardstats['G+A-PK_90']

# %%
standardstats_xga_90 = standardstats["npxG+xA_90"]

# %%
edited_standardstats1 = pd.concat([standardstats_names,standardstats_age],axis=1)

# %%
edited_standardstats2 = edited_standardstats1.join(standardstats_club)

# %%
edited_standardstats3 = edited_standardstats2.join(standardstats_pos)

# %%
edited_standardstats4 = edited_standardstats3.join(standardstats_ga_90)

# %%
edited_standardstats5 = edited_standardstats4.join(standardstats_xga_90)

# %%
final_df = pd.merge(final_df,edited_standardstats5,on='Player')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 76 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rk_x_x          395 non-null    int64
#  1   Player          395 non-null    object
#  2   Sh              395 non-null    int64
#  3   SoT             395 non-null    int64
#  4   SoT%            395 non-null    float64
#  5   Sh/90           395 non-null    float64
#  6   SoT/90          395 non-null    float64
#  7   G/Sh            395 non-null    float64
#  8   Dist            395 non-null    float64
#  9   npxG/Sh         395 non-null    float64
#  10  G-xG            395 non-null    float64
#  11  np:G-xG         395 non-null    float64
#  12  npxG_90         395 non-null    float64
#  13  Rk_y_x          395 non-null    int64
#  14  AirWon_x        395 non-null    int64
#  15  AirLost_x       395 non-null    int64
#  16  AirWon%_x       395 non-null    float64
# ...

# %%
final_df['Squad']
# Out:
# 0       Crystal Palace
# 1         Norwich City
# 2              Chelsea
# 3          Southampton
# 4      Manchester City
#             ...
# 390     Crystal Palace
# 391       Norwich City
# 392    Manchester City
# 393      Sheffield Utd
# 394            Chelsea
# Name: Squad, Length: 395, dtype: object

# %%
final_df.drop('Age_y',axis =1, inplace=True)
final_df.drop('AirWon_y', axis =1,inplace=True)
final_df.drop('AirLost_y', axis =1,inplace=True)
final_df.drop('AirWon%_y', axis = 1, inplace=True)
final_df.drop('Rk_x_x', axis = 1, inplace =True)
final_df.drop('Rk_y_x', axis = 1, inplace =True)
final_df.drop('Rk_x_y', axis = 1, inplace =True)
final_df.drop('Rk_y_y', axis = 1, inplace =True)
final_df.drop('Rk_y', axis = 1, inplace =True)
final_df.drop('Rk_x', axis = 1, inplace =True)
final_df.drop('xG+/-90_y', axis = 1, inplace =True)

# %%
str_to_num = {'Arsenal':1, 'Aston Villa':2, 'Bournemouth':3, 'Brighton':4, 'Burnley':5, "Chelsea":6 , 'Crystal Palace':7, 
              "Everton":8, 'Leicester City':9, 'Liverpool':10, 'Manchester City':11, 'Manchester Utd':12, 'Newcastle Utd':13,
             'Norwich City':14, 'Sheffield Utd':15, 'Southampton':16, 'Tottenham':17, 'Watford':18, 'West Ham':19, 
              'Wolves':20}

# %%
final_df['Squad']= final_df['Squad'].replace(str_to_num)

# %%
str_to_num2 = {'DF':1,'MF':2,'FW':3,'MF,FW':2,'FW,MF':3,'MF,DF':2,'DF,MF':1, 'DF,FW':1}

# %%
final_df['Pos']= final_df['Pos'].replace(str_to_num2)

# %%
final_df['Pos'].value_counts()
# Out:
# 1    154
# 2    141
# 3    100
# Name: Pos, dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          395 non-null    object
#  1   Sh              395 non-null    int64
#  2   SoT             395 non-null    int64
#  3   SoT%            395 non-null    float64
#  4   Sh/90           395 non-null    float64
#  5   SoT/90          395 non-null    float64
#  6   G/Sh            395 non-null    float64
#  7   Dist            395 non-null    float64
#  8   npxG/Sh         395 non-null    float64
#  9   G-xG            395 non-null    float64
#  10  np:G-xG         395 non-null    float64
#  11  npxG_90         395 non-null    float64
#  12  AirWon_x        395 non-null    int64
#  13  AirLost_x       395 non-null    int64
#  14  AirWon%_x       395 non-null    float64
#  15  Cmp             395 non-null    int64
#  16  Att_x           395 non-null    int64
# ...

# %%
# # utils.py
# import matplotlib.pyplot as plt
# from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

def evaluate(y_train, train_preds, y_test, test_preds, log=False):
    '''
    Evaluate the amount of error between my model's predictionms and the actual values
    for both a train and a test set
    
    Inputs: 
        y_train - array like, actual values for 'price for my train dataset
        train_preds - array like, predicted values for 'price' for my train dataset
        y_test
        test_preds
        log = False if our target isn't logged. We set log = true if our target is logged and needs to be unlogged.
    Outputs:
        None
    '''
    print(f"Train R2: {r2_score(y_train, train_preds):.4f}")
    print(f"Test R2: {r2_score(y_test, test_preds):.4f}")
    print("*****")
    if log == False:
        print(f"Train RMSE: {mean_squared_error(y_train, train_preds, squared=False):,.2f}")
        print(f"Test RMSE: {mean_squared_error(y_test, test_preds, squared=False):,.2f}")
        print("*****")
        print(f"Train MAE: {mean_absolute_error(y_train, train_preds):,.2f}")
        print(f"Test MAE: {mean_absolute_error(y_test, test_preds):,.2f}")
        print("*****")
    else:
        y_tr_unlog = np.exp(y_train)
        tr_pred_unlog=np.exp(train_preds)
        y_te_unlog=np.exp(y_test)
        te_pred_unlog=np.exp(test_preds)
        print(f"Train RMSE: {mean_squared_error(y_tr_unlog, tr_pred_unlog, squared=False):,.2f}")
        print(f"Test RMSE: {mean_squared_error(y_te_unlog, te_pred_unlog, squared=False):,.2f}")
        print("*****")
        print(f"Train MAE: {mean_absolute_error(y_tr_unlog, tr_pred_unlog):,.2f}")
        print(f"Test MAE: {mean_absolute_error(y_te_unlog, te_pred_unlog):,.2f}")
        print("*****")
    # Calculate our residuals 
    train_residuals = y_train - train_preds
    test_residuals = y_test - test_preds
    
    # Scatter plot 
    plt.scatter(train_preds, train_residuals, label = 'Train')
    plt.scatter(test_preds, test_residuals, label = 'Test')
    
    plt.axhline(y=0, color = 'red', label = '0')
    plt.xlabel('predictions')
    plt.ylabel('residuals')
    plt.legend()
    
    sm.qqplot(train_residuals, line = 'r', label = 'train residuals');
    plt.legend()
    
    sm.qqplot(test_residuals, line = 'r', label = 'test residuals');
    plt.legend()
    plt.show()

# %%
def next_possible_feature (X_tr, X_te, y_tr, y_te, current_features, ignore_features=[]):
    '''
    This function will loop through each column that isn't in your feature model and 
    calculate the r-squared value if it were the next feature added to your model. It will
    display a dataframe with a sorted r-squared value.
    X_tr = X_train dataframe
    X_te = X_test dataframe
    y_tr = y_train dataframe
    y_te = y_test dataframe
    current_features = list of features that are already in your model
    ignore_features = list of features we know are multicollinear that we want to skip over
    '''
    function_dict = {'predictor': [], 'test r-squared':[]}
    for col in X_tr.columns:
        if col not in (current_features+ignore_features) and X_tr[col].dtypes in ['int64', 'float64']:
            function_X_tr = X_tr[current_features + [col]]
            function_X_te = X_te[current_features + [col]]
            function_model  = sm.OLS(y_tr, sm.add_constant(function_X_tr)).fit()
            function_train_preds = function_model.predict(sm.add_constant(function_X_tr))
            function_test_preds = function_model.predict(sm.add_constant(function_X_te))
            function_dict['predictor'].append(col)
            function_dict['test r-squared'].append(r2_score(y_te, function_test_preds))
    function_df = pd.DataFrame(function_dict).sort_values(by=['test r-squared'], ascending = False)
    display(function_df)

# %% [markdown]
# # Attacking

# %%
#split our original dataframe into X and y variables
#drop id and price from the X dataframe
X = final_df.drop('npxG+xA_90', axis =1)
y = final_df['npxG+xA_90']

# %%
# Train - Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
#Bring the train and test dataframes back together
train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

# %%
# Absolute value correlations with price
plt.figure(figsize=(7,10))
sns.heatmap(abs(train_df.corr())[['npxG+xA_90']], annot=True);

# %%
np.abs(train_df.corr()['npxG+xA_90']).sort_values(ascending = False)
# Out:
# npxG+xA_90    1.000000
# npxG_90       0.926521
# Sh/90         0.895567
# SoT/90        0.864372
# G+A-PK_90     0.768060
#                 ...
# Rec           0.052084
# Age_x         0.037859
# Cmp%long      0.031589
# Prog_pass     0.023478
# Min           0.003466
# Name: npxG+xA_90, Length: 64, dtype: float64

# %%
# code here to arrive at a baseline prediction
train_target_mean = y_train.mean()
train_target_mean
# Out:
# 0.2272972972972973

# %%
#model baseline prediction
baseline_train_preds = [train_target_mean]*len(y_train)
baseline_test_preds = [train_target_mean]*len(y_test)
evaluate(y_train, baseline_train_preds, y_test, baseline_test_preds)
# Out:
# Train R2: 0.0000
# Test R2: -0.0057
# *****
# Train RMSE: 0.20
# Test RMSE: 0.18
# *****
# Train MAE: 0.15
# Test MAE: 0.15
# *****

# %%
np.abs(train_df.corr()['npxG+xA_90']).sort_values(ascending = False)
# Out:
# npxG+xA_90    1.000000
# npxG_90       0.926521
# Sh/90         0.895567
# SoT/90        0.864372
# G+A-PK_90     0.768060
#                 ...
# Rec           0.052084
# Age_x         0.037859
# Cmp%long      0.031589
# Prog_pass     0.023478
# Min           0.003466
# Name: npxG+xA_90, Length: 64, dtype: float64

# %%
# My first 'substandard' model
fsm_X_train= X_train['SoT/90']
fsm_X_test = X_test['SoT/90']
fsm = sm.OLS(y_train, sm.add_constant(fsm_X_train)).fit()
fsm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.746
# Method:                 Least Squares   F-statistic:                     868.7
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):           8.99e-90
# Time:                        19:55:19   Log-Likelihood:                 261.03
# No. Observations:                 296   AIC:                            -518.1
# Df Residuals:                     294   BIC:                            -510.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0559      0.008      6.774      0.000       0.040       0.072
# ...

# %%
# Evaluation of my first 'substandard' model
fsm_train_preds = fsm.predict(sm.add_constant(fsm_X_train))
fsm_test_preds = fsm.predict(sm.add_constant(fsm_X_test))

evaluate(y_train, fsm_train_preds, y_test, fsm_test_preds)
# Out:
# Train R2: 0.7471
# Test R2: 0.8185
# *****
# Train RMSE: 0.10
# Test RMSE: 0.08
# *****
# Train MAE: 0.07
# Test MAE: 0.06
# *****

# %%
selected_features = ['SoT/90']
features_to_ignore = ['xA_90','npxG_90','G+A-PK_90','Ast_90']
next_possible_feature (X_tr=X_train, X_te=X_test, y_tr=y_train, \
                       y_te=y_test, current_features=selected_features, \
                       ignore_features=features_to_ignore)
# Out:
#          predictor  test r-squared
# 18              KP        0.838226
# 3            Sh/90        0.837759
# 11       AirWon%_x        0.835979
# 22        PassLive        0.835090
# 2             SoT%        0.832323
# 53        Prog_rec        0.831139
# 38             Clr        0.831079
# 55             Fld        0.824167
# 16         Cmp%med        0.824104
# 47       Prog_drib        0.822938
# 57             Pos        0.822890
# 21         Blocked        0.822705
# 23        PassDead        0.822674
# 41           Recov        0.822096
# 52            Rec%        0.821990
# 7             G-xG        0.821379
# 40       xG+/-90_x        0.821247
# 37             Int        0.821051
# 8          np:G-xG        0.820959
# 36          Blocks        0.820566
# 45           Succ%        0.820426
# 0               Sh        0.819905
# 14            Cmp%        0.819777
# 54            Drib        0.819756
# 4             G/Sh        0.819678
# 5             Dist        0.819603
# ...

# %%
second_predictors = ['SoT/90', 'KP']
second_X_train= X_train[second_predictors]
second_X_test = X_test[second_predictors]
second_model = sm.OLS(y_train, sm.add_constant(second_X_train)).fit()
second_train_preds = second_model.predict(sm.add_constant(second_X_train))
second_test_preds = second_model.predict(sm.add_constant(second_X_test))
evaluate(y_train, second_train_preds , y_test, second_test_preds, log=True)
# Out:
# Train R2: 0.7666
# Test R2: 0.8382
# *****
# Train RMSE: 0.16
# Test RMSE: 0.09
# *****
# Train MAE: 0.09
# Test MAE: 0.07
# *****

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# defining an empty dataframe to capture the VIF scores
vif_2 = pd.DataFrame()

# label the scores with their related columns
vif_2["features"] = second_X_train.columns

# For each column,run a variance_inflaction_factor against all other columns to get a VIF Factor score

vif_2["VIF"] = [variance_inflation_factor(second_X_train.values, i) \
                for i in range(len(second_X_train.columns))]

vif_2
# Out:
#   features       VIF
# 0   SoT/90  1.733164
# 1       KP  1.733164

# %%
second_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     481.2
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):           2.64e-93
# Time:                        20:42:52   Log-Likelihood:                 272.90
# No. Observations:                 296   AIC:                            -539.8
# Df Residuals:                     293   BIC:                            -528.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0364      0.009      4.110      0.000       0.019       0.054
# ...

# %%
selected_features = ['SoT/90','KP']
features_to_ignore = ['xA_90','npxG_90','G+A-PK_90','Ast_90']
next_possible_feature (X_tr=X_train, X_te=X_test, y_tr=y_train, \
                       y_te=y_test, current_features=selected_features, \
                       ignore_features=features_to_ignore)
# Out:
#          predictor  test r-squared
# 25             Min        0.864031
# 40           Recov        0.863615
# 35          Blocks        0.860530
# 33       PressSucc        0.856566
# 2             SoT%        0.856140
# 32           Press        0.856052
# 26             Tkl        0.855802
# 27            TklW        0.855251
# 36             Int        0.852738
# 31  PlayersLetPast        0.852562
# 41         Touches        0.852171
# 11       AirWon%_x        0.850903
# 29           Att_d        0.850850
# 3            Sh/90        0.850375
# 24              MP        0.848971
# 37             Clr        0.848703
# 13           Att_x        0.848222
# 12             Cmp        0.847854
# 50             Rec        0.846710
# 5             Dist        0.844901
# 49            Targ        0.844597
# 16         Cmp%med        0.844102
# 8          np:G-xG        0.843958
# 7             G-xG        0.843944
# 28           Tkl_d        0.843915
# 42            Succ        0.843858
# ...

# %%
# defining an empty dataframe to capture the VIF scores
vif_3 = pd.DataFrame()

third_X_train = X_train[['SoT/90', 'KP', 'SoT%']]

# label the scores with their related columns
vif_3["features"] = third_X_train.columns

# For each column,run a variance_inflaction_factor against all other columns to get a VIF Factor score

vif_3["VIF"] = [variance_inflation_factor(third_X_train.values, i) \
                for i in range(len(third_X_train.columns))]

vif_3
# Out:
#   features       VIF
# 0   SoT/90  2.968675
# 1       KP  1.889183
# 2     SoT%  2.962646

# %%
third_predictors = ['SoT/90', 'KP', 'SoT%']
third_X_train= X_train[third_predictors]
third_X_test = X_test[third_predictors]
third_model = sm.OLS(y_train, sm.add_constant(third_X_train)).fit()
third_train_preds = third_model.predict(sm.add_constant(third_X_train))
third_test_preds = third_model.predict(sm.add_constant(third_X_test))
evaluate(y_train, third_train_preds , y_test, third_test_preds, log=True)
# Out:
# Train R2: 0.7985
# Test R2: 0.8561
# *****
# Train RMSE: 0.15
# Test RMSE: 0.09
# *****
# Train MAE: 0.09
# Test MAE: 0.06
# *****

# %%
third_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     385.8
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):          3.16e-101
# Time:                        20:42:53   Log-Likelihood:                 294.67
# No. Observations:                 296   AIC:                            -581.3
# Df Residuals:                     292   BIC:                            -566.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0868      0.011      7.832      0.000       0.065       0.109
# ...

# %%
# code here to iteratively improve your models
selected_features = ['SoT/90', 'KP', 'SoT%']
features_to_ignore = ['xA_90','npxG_90','G+A-PK_90','Ast_90','Recov','G/Sh','TklW','Tkl','SoT/90']
next_possible_feature (X_tr=X_train, X_te=X_test, y_tr=y_train, \
                       y_te=y_test, current_features=selected_features, \
                       ignore_features=features_to_ignore)
# Out:
#          predictor  test r-squared
# 23             Min        0.877213
# 29       PressSucc        0.870482
# 28           Press        0.870021
# 31          Blocks        0.869248
# 36         Touches        0.866462
# 33             Clr        0.865673
# 27  PlayersLetPast        0.865251
# 32             Int        0.864556
# 22              MP        0.864326
# 25           Att_d        0.864211
# 39           Succ%        0.863575
# 45             Rec        0.862941
# 9        AirWon%_x        0.862889
# 11           Att_x        0.862758
# 10             Cmp        0.862737
# 44            Targ        0.862227
# 37            Succ        0.862158
# 43             Dis        0.861970
# 40      plyrs_past        0.861949
# 14         Cmp%med        0.861021
# 38           Att_y        0.860970
# 34             Err        0.860545
# 0               Sh        0.860277
# 1              SoT        0.860089
# 16       Prog_pass        0.859823
# 24           Tkl_d        0.859731
# ...

# %%
# defining an empty dataframe to capture the VIF scores
vif_4 = pd.DataFrame()

fourth_X_train = X_train[['SoT/90', 'KP','SoT%','PressSucc']]

# label the scores with their related columns
vif_4["features"] = fourth_X_train.columns

# For each column,run a variance_inflaction_factor against all other columns to get a VIF Factor score

vif_4["VIF"] = [variance_inflation_factor(fourth_X_train.values, i) \
                for i in range(len(fourth_X_train.columns))]

vif_4
# Out:
#     features       VIF
# 0     SoT/90  2.991993
# 1         KP  3.468459
# 2       SoT%  3.788319
# 3  PressSucc  4.441353

# %%
fourth_predictors = ['SoT/90', 'KP','SoT%','PressSucc']
fourth_X_train= X_train[fourth_predictors]
fourth_X_test = X_test[fourth_predictors]
fourth_model = sm.OLS(y_train, sm.add_constant(fourth_X_train)).fit()
fourth_train_preds = fourth_model.predict(sm.add_constant(fourth_X_train))
fourth_test_preds = fourth_model.predict(sm.add_constant(fourth_X_test))
evaluate(y_train, fourth_train_preds , y_test, fourth_test_preds, log=True)
# Out:
# Train R2: 0.8110
# Test R2: 0.8705
# *****
# Train RMSE: 0.14
# Test RMSE: 0.08
# *****
# Train MAE: 0.08
# Test MAE: 0.06
# *****

# %%
fourth_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     312.2
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):          6.17e-104
# Time:                        20:42:55   Log-Likelihood:                 304.14
# No. Observations:                 296   AIC:                            -598.3
# Df Residuals:                     291   BIC:                            -579.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1125      0.012      9.188      0.000       0.088       0.137
# ...

# %%
# code here to iteratively improve your models
selected_features = ['SoT/90', 'KP','SoT%','PressSucc']
features_to_ignore = ['xA_90','npxG_90','G+A-PK_90','Ast_90','Recov','G/Sh','TklW','Tkl','SoT/90']
next_possible_feature (X_tr=X_train, X_te=X_test, y_tr=y_train, \
                       y_te=y_test, current_features=selected_features, \
                       ignore_features=features_to_ignore)
# Out:
#          predictor  test r-squared
# 23             Min        0.877203
# 20        PassDead        0.876075
# 9        AirWon%_x        0.875892
# 46        Prog_rec        0.875728
# 14         Cmp%med        0.875009
# 38           Succ%        0.874518
# 32             Clr        0.874274
# 34       xG+/-90_x        0.873386
# 30          Blocks        0.872745
# 49           Squad        0.872614
# 3             Dist        0.872552
# 33             Err        0.872522
# 6          np:G-xG        0.871745
# 35         Touches        0.871297
# 5             G-xG        0.871277
# 36            Succ        0.870831
# 21           Age_x        0.870782
# 39      plyrs_past        0.870709
# 17         PassInt        0.870677
# 10             Cmp        0.870632
# 8        AirLost_x        0.870607
# 28           Press        0.870584
# 13       Cmp%short        0.870541
# 31             Int        0.870531
# 47            Drib        0.870514
# 41             Mis        0.870514
# ...

# %%
 #defining an empty dataframe to capture the VIF scores
vif_5 = pd.DataFrame()

fifth_X_train = X_train[['SoT/90', 'KP', 'SoT%','PressSucc','Succ%']]

# label the scores with their related columns
vif_5["features"] = fifth_X_train.columns

# For each column,run a variance_inflaction_factor against all other columns to get a VIF Factor score

vif_5["VIF"] = [variance_inflation_factor(fifth_X_train.values, i) \
                for i in range(len(fifth_X_train.columns))]

vif_5
# Out:
#     features       VIF
# 0     SoT/90  3.007298
# 1         KP  3.479705
# 2       SoT%  5.008099
# 3  PressSucc  5.461688
# 4      Succ%  4.269837

# %%
fifth_predictors = ['SoT/90', 'KP','SoT%','PressSucc','Succ%']
fifth_X_train= X_train[fifth_predictors]
fifth_X_test = X_test[fifth_predictors]
fifth_model = sm.OLS(y_train, sm.add_constant(fifth_X_train)).fit()
fifth_train_preds = fifth_model.predict(sm.add_constant(fifth_X_train))
fifth_test_preds = fifth_model.predict(sm.add_constant(fifth_X_test))
evaluate(y_train, fifth_train_preds , y_test, fifth_test_preds, log=True)
# Out:
# Train R2: 0.8156
# Test R2: 0.8745
# *****
# Train RMSE: 0.14
# Test RMSE: 0.08
# *****
# Train MAE: 0.08
# Test MAE: 0.06
# *****

# %%
fifth_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     256.5
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):          3.49e-104
# Time:                        20:42:59   Log-Likelihood:                 307.73
# No. Observations:                 296   AIC:                            -603.5
# Df Residuals:                     290   BIC:                            -581.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1621      0.022      7.307      0.000       0.118       0.206
# ...

# %% [markdown]
# # Final Attacking Model

# %%
# code here to show your final model
final_predictors = ['SoT/90', 'KP','SoT%','PressSucc','Succ%']
final_X_train= X_train[final_predictors]
final_X_test = X_test[final_predictors]
final_attacking_model = sm.OLS(y_train, sm.add_constant(final_X_train)).fit()
final_train_preds = final_attacking_model.predict(sm.add_constant(final_X_train))
final_test_preds = final_attacking_model.predict(sm.add_constant(final_X_test))
evaluate(y_train, final_train_preds , y_test, final_test_preds, log=True)
# Out:
# Train R2: 0.8156
# Test R2: 0.8745
# *****
# Train RMSE: 0.14
# Test RMSE: 0.08
# *****
# Train MAE: 0.08
# Test MAE: 0.06
# *****

# %%
# code here to evaluate your final model
final_attacking_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             npxG+xA_90   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     256.5
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):          3.49e-104
# Time:                        20:47:19   Log-Likelihood:                 307.73
# No. Observations:                 296   AIC:                            -603.5
# Df Residuals:                     290   BIC:                            -581.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1621      0.022      7.307      0.000       0.118       0.206
# ...
